# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.2 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pFDExbvIXlr4juKr5Dlq")
project = rf.workspace("s-workspace-rcyvl").project("yolo-zpurj")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/프로젝트 4조/Road/baseline_2000_imgs_640/weights/best.pt')

results = model.predict(
    source='/content/YOLO-10/test/images',
    save=True,
    conf=0.05,
    imgsz=640,
    rect=True,
    line_width=1,
    device='cpu'
)

print("done")
# Out:
# image 1/99 /content/YOLO-10/test/images/test_frame_000_jpg.rf.ba28cb2ed4cb66353c5d9173889e6226.jpg: 640x640 1 Manhole, 390.9ms
# image 2/99 /content/YOLO-10/test/images/test_frame_001_jpg.rf.83bc51af4b43dac5573f8244f259dc68.jpg: 640x640 (no detections), 503.2ms
# image 3/99 /content/YOLO-10/test/images/test_frame_002_jpg.rf.d7d17d076a4480744e4361789c443c23.jpg: 640x640 (no detections), 445.0ms
# image 4/99 /content/YOLO-10/test/images/test_frame_003_jpg.rf.d44c6c195c0c97f97b7e77a831755558.jpg: 640x640 1 Crack, 453.5ms
# image 5/99 /content/YOLO-10/test/images/test_frame_004_jpg.rf.ecd615a60e167fb3d221bcb988c4ffa1.jpg: 640x640 1 Manhole, 443.7ms
# image 6/99 /content/YOLO-10/test/images/test_frame_005_jpg.rf.89f1665539048462a50ebcfbf9073a18.jpg: 640x640 2 Manholes, 409.0ms
# image 7/99 /content/YOLO-10/test/images/test_frame_006_jpg.rf.6d29bd917d04831ab5b0d042474b6b41.jpg: 640x640 (no detections), 346.9ms
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/local_model_m_640_cropped-2/weights/best.pt')

results = model.predict(
    source='/content/YOLO-10/test/images',
    save=True,
    conf=0.05,
    imgsz=640,
    rect=True,
    line_width=1,
    device='cpu'
)

print("done")
# Out:
# image 1/99 /content/YOLO-10/test/images/test_frame_000_jpg.rf.ba28cb2ed4cb66353c5d9173889e6226.jpg: 640x640 1 Manhole, 984.8ms
# image 2/99 /content/YOLO-10/test/images/test_frame_001_jpg.rf.83bc51af4b43dac5573f8244f259dc68.jpg: 640x640 2 Manholes, 1335.6ms
# image 3/99 /content/YOLO-10/test/images/test_frame_002_jpg.rf.d7d17d076a4480744e4361789c443c23.jpg: 640x640 (no detections), 1290.7ms
# image 4/99 /content/YOLO-10/test/images/test_frame_003_jpg.rf.d44c6c195c0c97f97b7e77a831755558.jpg: 640x640 2 Manholes, 978.5ms
# image 5/99 /content/YOLO-10/test/images/test_frame_004_jpg.rf.ecd615a60e167fb3d221bcb988c4ffa1.jpg: 640x640 (no detections), 977.9ms
# image 6/99 /content/YOLO-10/test/images/test_frame_005_jpg.rf.89f1665539048462a50ebcfbf9073a18.jpg: 640x640 (no detections), 974.4ms
# image 7/99 /content/YOLO-10/test/images/test_frame_006_jpg.rf.6d29bd917d04831ab5b0d042474b6b41.jpg: 640x640 (no detections), 992.9ms
# ...
